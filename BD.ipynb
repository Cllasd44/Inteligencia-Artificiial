# %% [markdown]
# <a href="https://colab.research.google.com/github/Cllasd44/Inteligencia-Artificiial/blob/main/BD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
movies = pd.read_csv("/content/movies.csv")
ratings = pd.read_csv("/content/ratings.csv")
tags = pd.read_csv("/content/tags.csv")

# %%
ratings.head(3)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224

# %%
movies.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
tags.head(3)
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992

# %%
#del movies['genres']
del ratings['timestamp']
del tags['timestamp']

# %%
tags.head(2)
# Out:
#    userId  movieId              tag
# 0       2    60756            funny
# 1       2    60756  Highly quotable

# %%
movies.head(2)
# Out:
#    movieId             title                                       genres
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        2    Jumanji (1995)                   Adventure|Children|Fantasy

# %%
ratings.head(2)
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0

# %%
print(movies.index)
# Out:
# RangeIndex(start=0, stop=9742, step=1)

# %%
print(ratings.index)
# Out:
# RangeIndex(start=0, stop=100836, step=1)

# %%
print(tags.index)
# Out:
# RangeIndex(start=0, stop=3683, step=1)

# %%
print(movies.columns)
print(ratings.columns)
print(tags.columns)
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')
# Index(['userId', 'movieId', 'rating'], dtype='object')
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
ratings.head(2)
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0

# %%
print(ratings['rating'].describe)
# Out:
# <bound method NDFrame.describe of 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: rating, Length: 100836, dtype: float64>

# %%
print(ratings['rating'].min)
# Out:
# <bound method Series.min of 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: rating, Length: 100836, dtype: float64>

# %%
print(ratings['rating'].max)
# Out:
# <bound method Series.max of 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: rating, Length: 100836, dtype: float64>

# %%
print(ratings['rating'].std)
# Out:
# <bound method Series.std of 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: rating, Length: 100836, dtype: float64>

# %%
print(ratings['rating'].mode)
# Out:
# <bound method Series.mode of 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: rating, Length: 100836, dtype: float64>

# %%
ratings.shape
# Out:
# (100836, 3)

# %%
movies.shape
# Out:
# (9742, 3)

# %%
tags.shape
# Out:
# (3683, 3)

# %%
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
# %matplotlib inline
ratings.hist(column='rating',figsize=(10,7))
# Out:
# array([[<Axes: title={'center': 'rating'}>]], dtype=object)

# %%
tags.head(10)
# Out:
#    userId  movieId                tag
# 0       2    60756              funny
# 1       2    60756    Highly quotable
# 2       2    60756       will ferrell
# 3       2    89774       Boxing story
# 4       2    89774                MMA
# 5       2    89774          Tom Hardy
# 6       2   106782              drugs
# 7       2   106782  Leonardo DiCaprio
# 8       2   106782    Martin Scorsese
# 9       7    48516       way too long

# %%
data = pd.read_csv('tags.csv')
data.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
unique_labels = data['tag'].unique()
print(unique_labels)
# Out:
# ['funny' 'Highly quotable' 'will ferrell' ... 'gun fu' 'heroic bloodshed'
#  'Heroic Bloodshed']

# %%
print(len(unique_labels))
# Out:
# 1589

# %%
movies.head(4)
# Out:
#    movieId                     title  \
# 0        1          Toy Story (1995)
# 1        2            Jumanji (1995)
# 2        3   Grumpier Old Men (1995)
# 3        4  Waiting to Exhale (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance

# %%
ratings.head(3)
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0

# %%
tgs_count=tags['tag'].value_counts()

# %%
tags['tag'].value_counts()
# Out:
# tag
# In Netflix queue     131
# atmospheric           36
# thought-provoking     24
# superhero             24
# funny                 23
#                     ...
# small towns            1
# In Your Eyes           1
# Lloyd Dobbler          1
# weak plot              1
# Heroic Bloodshed       1
# Name: count, Length: 1589, dtype: int64

# %%
type(tgs_count)
# Out:
# pandas.core.series.Series

# %%
tgs_count[:10].plot(kind='bar', figsize=(5,10))
# Out:
# <Axes: xlabel='tag'>

# %%
ratings_filtered = ratings[(ratings['rating'] >= 4) & (ratings['rating'] <= 5)]
num_movies_filtered = len(ratings_filtered)
print(f"Número de películas con calificaciones entre 4 y 5: {num_movies_filtered}")
# Out:
# Número de películas con calificaciones entre 4 y 5: 48580

# %%
print(ratings_filtered)
# Out:
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100830     610   166528     4.0
# 100831     610   166534     4.0
# 100832     610   168248     5.0
# 100833     610   168250     5.0
# 100834     610   168252     5.0
#
# [48580 rows x 3 columns]

# %%
print(ratings_filtered.head(3))
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0

# %%
movies.head(4)
# Out:
#    movieId                     title  \
# 0        1          Toy Story (1995)
# 1        2            Jumanji (1995)
# 2        3   Grumpier Old Men (1995)
# 3        4  Waiting to Exhale (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance

# %%
animacion_df = movies[movies['genres'].str.contains("Animacion", case=False)]

# %%
filtro=movies['genres'].str.contains('Animation')
print(filtro.shape)
# Out:
# (9742,)

# %%
movies[filtro].shape
# Out:
# (611, 3)
